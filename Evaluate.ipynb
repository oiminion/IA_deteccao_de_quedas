# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import json

NETWORK_NAME = "LSTM_f1_81"

# %%
cm = np.load(f"Metrics/{NETWORK_NAME}_Confusion.npy")
class_enum = []
class_names = ['ADL', 'Caindo']

# Set up the matplotlib figure
plt.figure(figsize=(4, 4))

# Create the heatmap
sns.heatmap(
    cm, 
    annot=True,
    fmt='d',              
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

# Add labels and title
plt.ylabel('Verdadeiro')
plt.xlabel('Predito')
plt.title('Matriz de confusão')

# Show the plot
plt.tight_layout()
plt.show()

# %%
cm = np.load(f"Metrics/{NETWORK_NAME}_Normalized_Confusion.npy")
class_enum = []
class_names = ['ADL', 'Caindo']

# Set up the matplotlib figure
plt.figure(figsize=(4, 4))

# Create the heatmap
sns.heatmap(
    cm, 
    annot=True,
    fmt='.3f',              
    cmap='Blues',
    xticklabels=class_names,
    yticklabels=class_names
)

# Add labels and title
plt.ylabel('Verdadeiro')
plt.xlabel('Predito')
plt.title('Matriz de confusão')

# Show the plot
plt.tight_layout()
plt.show()
